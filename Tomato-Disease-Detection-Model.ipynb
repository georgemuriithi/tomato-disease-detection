# %% [markdown]
# ### 1. Importing packages

# %%
# !pip install split-folders

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# checking gpu support
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tabulate import tabulate

# %%
# import splitfolders
import os
import numpy as np
import pandas as pd
import random

# %% [markdown]
# ### 2. Loading dataset

# %%
# defining constants
BATCH_SIZE = 32
IMG_SIZE = 256
EPOCHS = 50

# %%
# project's main directory
prj_dir = '/content/drive/My Drive/Projects/Tomato-disease-detection'

# %%
# building tf input data pipeline
ds = tf.keras.utils.image_dataset_from_directory(
    f'{prj_dir}/Data', 
    batch_size=BATCH_SIZE, 
    image_size=(IMG_SIZE, IMG_SIZE), 
    shuffle=True
)
# Out:
# Found 7325 files belonging to 8 classes.

# %%
# getting class names
class_names = ds.class_names
class_names
# Out:
# ['Bacterial-spot',
#  'Early-blight',
#  'Healthy',
#  'Late-blight',
#  'Leaf-mold',
#  'Mosaic-virus',
#  'Septoria-leaf-spot',
#  'Yellow-leaf-curl-virus']

# %%
# displaying sample data
img = None

plt.figure(figsize=(12, 12))

for imgs, lbls in ds.take(1):
    print(f'Batch 1 Imgs shape: {imgs.shape}')
    print(f'Batch 1 Lbls: {lbls.numpy()}')

    img = imgs[0].numpy().astype('uint8') # taking sample image
    
    for i in range(12):
        plt.subplot(3, 4, i + 1)
        plt.imshow(imgs[i].numpy().astype('uint8'))
        plt.title(class_names[lbls[i]])
        plt.axis('off')
# Out:
# Batch 1 Imgs shape: (32, 256, 256, 3)
# Batch 1 Lbls: [0 2 4 4 3 0 3 7 4 4 2 7 1 4 4 3 2 4 2 6 5 1 2 3 4 7 7 4 1 3 2 6]

# %% [markdown]
# ### 3. Data preprocessing

# %%
# creating training set, validation set and testing set
ds_size = len(ds)

ds = ds.shuffle(10000, seed=12)

# taking 10% for testing set and dividing remaining into 80/20 training/validation ratio
train_size = int(ds_size * 0.72) # 72%
train_set = ds.take(train_size)

val_size = int(ds_size * 0.18) # 18%
val_set = ds.skip(train_size).take(val_size)

test_set = ds.skip(train_size).skip(val_size)
test_size = len(test_set) # 10%

print(f'Dataset size   : {ds_size}')
print(f'Train set size : {train_size}')
print(f'Val set size   : {val_size}')
print(f'Test set size  : {test_size}')
# Out:
# Dataset size   : 229
# Train set size : 164
# Val set size   : 41
# Test set size  : 24

# %%
# optimizing tf input data pipeline performance

# caching for epochs
# prefetching tf-determined data into CPU as GPU computes - AUTOTUNE
train_set = train_set.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_set = val_set.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_set = test_set.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# resizing and rescaling layers
resize_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE), # during prediction
    layers.experimental.preprocessing.Rescaling(1.0 / 255) # rescaling rgb values to between 0.0 and 1.0
])

# %%
# data augmentation to make model robust and prevent overfitting
data_aug = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal_and_vertical'), 
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
# testing data augmentation
imgs = [img, data_aug(img).numpy().astype('uint8')]
titles = ['Original', 'Augmented']
for i in range(2):
    plt.subplot(1, 2, i + 1)
    plt.imshow(imgs[i])
    plt.title(titles[i])
    plt.axis('off')

# %%
# applying data augmentation to training set
train_set = train_set.map(
    lambda x, y: (data_aug(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# splitfolders.ratio(f'{prj_dir}/Data', 
#                    output=f'{prj_dir}/Subsets', 
#                    ratio=(.72, .18, .10)
#                    )

# %%
# train_imgs_gen = ImageDataGenerator(
#     rescale=1.0 / 255, 
#     horizontal_flip=True, 
#     vertical_flip=True, 
#     rotation_range=20
# )

# train_data_gen = train_imgs_gen.flow_from_directory(
#     f'{prj_dir}/Subsets/train', 
#     target_size=(IMG_SIZE, IMG_SIZE), 
#     batch_size=BATCH_SIZE, 
#     class_mode='sparse', # integer labels
#     # save_to_dir=f'{prj_dir}/Subsets/aug_train'
# )

# same for validation and testing sets

# %%
# for imgs, lbls in train_data_gen:
#     print(imgs.shape)
#     break

# %% [markdown]
# ### 4. Model building

# %%
# building model with alternating Conv2D and MaxPooling2D layers
input_shape = (BATCH_SIZE, IMG_SIZE, IMG_SIZE, 3) # 3 channels - rgb
n_classes = len(class_names)

model = models.Sequential([
    resize_rescale, # layers.InputLayer(input_shape=input_shape) # using data generator
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape), 
    layers.MaxPooling2D((2, 2)), 
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'), 
    layers.MaxPooling2D((2, 2)), 
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'), 
    layers.MaxPooling2D((2, 2)), 
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'), 
    layers.MaxPooling2D((2, 2)), 
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'), 
    layers.MaxPooling2D((2, 2)), 
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'), 
    layers.MaxPooling2D((2, 2)), 
    layers.Flatten(), 
    layers.Dense(units=64, activation='relu'), 
    layers.Dense(units=n_classes, activation='softmax')
])

# %%
model.build(input_shape=input_shape)

# %%
model.summary() # all trainable parameters -> no transfer learning
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 8)                   520
#
# =================================================================
# Total params: 184,072
# Trainable params: 184,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling model with optimizer, loss and metrics
model.compile(
    optimizer='adam', 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), 
    metrics=['accuracy']
)

# %% [markdown]
# ### 5. Model fitting

# %%
train_dir = f'{prj_dir}/Training' # training directory

# %%
train_ver = len(os.listdir(train_dir)) # latest saved training
print(f'Latest saved training ver: {train_ver}')
# Out:
# Latest saved training ver: 0

# %%
cps_dir = 'training-1/cp-{epoch:04d}.ckpt' # checkpoints directory

# %%
# callback to save model's weights at every epoch
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=cps_dir, 
    verbose=1, 
    save_weights_only=True
)

# saving weights
model.save_weights(cps_dir.format(epoch=0))

# fitting model
history = model.fit( # using data generator
    train_set, # train_data_gen
    epochs=EPOCHS, # , steps_per_epoch=train_imgs / BATCH_SIZE
    batch_size=BATCH_SIZE, 
    callbacks=[cp_callback], 
    validation_data=val_set, # validation_data=val_data_gen, validation_steps=val_imgs / BATCH_SIZE
    verbose=1
)
# Out:
# Epoch 1/50
# 164/164 [==============================] - ETA: 0s - loss: 1.8134 - accuracy: 0.2938
# Epoch 1: saving model to training-1/cp-0001.ckpt
# 164/164 [==============================] - 174s 482ms/step - loss: 1.8134 - accuracy: 0.2938 - val_loss: 1.8995 - val_accuracy: 0.3803
# Epoch 2/50
# 164/164 [==============================] - ETA: 0s - loss: 1.2924 - accuracy: 0.5283
# Epoch 2: saving model to training-1/cp-0002.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 1.2924 - accuracy: 0.5283 - val_loss: 1.2422 - val_accuracy: 0.5739
# Epoch 3/50
# 164/164 [==============================] - ETA: 0s - loss: 1.0704 - accuracy: 0.6063
# Epoch 3: saving model to training-1/cp-0003.ckpt
# 164/164 [==============================] - 55s 333ms/step - loss: 1.0704 - accuracy: 0.6063 - val_loss: 1.1480 - val_accuracy: 0.6143
# Epoch 4/50
# 164/164 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.6709
# Epoch 4: saving model to training-1/cp-0004.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.8773 - accuracy: 0.6709 - val_loss: 1.0503 - val_accuracy: 0.6494
# Epoch 5/50
# 164/164 [==============================] - ETA: 0s - loss: 0.7768 - accuracy: 0.7224
# Epoch 5: saving model to training-1/cp-0005.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.7768 - accuracy: 0.7224 - val_loss: 0.9304 - val_accuracy: 0.6753
# Epoch 6/50
# 164/164 [==============================] - ETA: 0s - loss: 0.6613 - accuracy: 0.7594
# Epoch 6: saving model to training-1/cp-0006.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.6613 - accuracy: 0.7594 - val_loss: 1.3343 - val_accuracy: 0.6372
# Epoch 7/50
# 164/164 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.7920
# Epoch 7: saving model to training-1/cp-0007.ckpt
# 164/164 [==============================] - 54s 332ms/step - loss: 0.5722 - accuracy: 0.7920 - val_loss: 1.5779 - val_accuracy: 0.5777
# Epoch 8/50
# 164/164 [==============================] - ETA: 0s - loss: 0.5119 - accuracy: 0.8116
# Epoch 8: saving model to training-1/cp-0008.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.5119 - accuracy: 0.8116 - val_loss: 0.6159 - val_accuracy: 0.7851
# Epoch 9/50
# 164/164 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8347
# Epoch 9: saving model to training-1/cp-0009.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.4659 - accuracy: 0.8347 - val_loss: 0.3977 - val_accuracy: 0.8681
# Epoch 10/50
# 164/164 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8450
# Epoch 10: saving model to training-1/cp-0010.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.4360 - accuracy: 0.8450 - val_loss: 0.6974 - val_accuracy: 0.7736
# Epoch 11/50
# 164/164 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8414
# Epoch 11: saving model to training-1/cp-0011.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.4256 - accuracy: 0.8414 - val_loss: 0.5433 - val_accuracy: 0.8232
# Epoch 12/50
# 164/164 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.8673
# Epoch 12: saving model to training-1/cp-0012.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.3656 - accuracy: 0.8673 - val_loss: 0.3830 - val_accuracy: 0.8636
# Epoch 13/50
# 164/164 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.8694
# Epoch 13: saving model to training-1/cp-0013.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.3582 - accuracy: 0.8694 - val_loss: 0.5313 - val_accuracy: 0.7980
# Epoch 14/50
# 164/164 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8890
# Epoch 14: saving model to training-1/cp-0014.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.3060 - accuracy: 0.8890 - val_loss: 0.4724 - val_accuracy: 0.8407
# Epoch 15/50
# 164/164 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.8843
# Epoch 15: saving model to training-1/cp-0015.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.3286 - accuracy: 0.8843 - val_loss: 0.6138 - val_accuracy: 0.8034
# Epoch 16/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9087
# Epoch 16: saving model to training-1/cp-0016.ckpt
# 164/164 [==============================] - 55s 333ms/step - loss: 0.2666 - accuracy: 0.9087 - val_loss: 0.5046 - val_accuracy: 0.8415
# Epoch 17/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2828 - accuracy: 0.9039
# Epoch 17: saving model to training-1/cp-0017.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.2828 - accuracy: 0.9039 - val_loss: 0.3620 - val_accuracy: 0.8704
# Epoch 18/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9140
# Epoch 18: saving model to training-1/cp-0018.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.2490 - accuracy: 0.9140 - val_loss: 0.3452 - val_accuracy: 0.8880
# Epoch 19/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.9117
# Epoch 19: saving model to training-1/cp-0019.ckpt
# 164/164 [==============================] - 54s 332ms/step - loss: 0.2548 - accuracy: 0.9117 - val_loss: 0.8110 - val_accuracy: 0.7538
# Epoch 20/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9125
# Epoch 20: saving model to training-1/cp-0020.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.2505 - accuracy: 0.9125 - val_loss: 0.3162 - val_accuracy: 0.8918
# Epoch 21/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9245
# Epoch 21: saving model to training-1/cp-0021.ckpt
# 164/164 [==============================] - 55s 338ms/step - loss: 0.2118 - accuracy: 0.9245 - val_loss: 0.2330 - val_accuracy: 0.9177
# Epoch 22/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9398
# Epoch 22: saving model to training-1/cp-0022.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.1698 - accuracy: 0.9398 - val_loss: 0.2507 - val_accuracy: 0.9139
# Epoch 23/50
# 164/164 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9165
# Epoch 23: saving model to training-1/cp-0023.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.2442 - accuracy: 0.9165 - val_loss: 0.3538 - val_accuracy: 0.8788
# Epoch 24/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9342
# Epoch 24: saving model to training-1/cp-0024.ckpt
# 164/164 [==============================] - 56s 339ms/step - loss: 0.1877 - accuracy: 0.9342 - val_loss: 0.3080 - val_accuracy: 0.8910
# Epoch 25/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9342
# Epoch 25: saving model to training-1/cp-0025.ckpt
# 164/164 [==============================] - 55s 333ms/step - loss: 0.1811 - accuracy: 0.9342 - val_loss: 0.3457 - val_accuracy: 0.8887
# Epoch 26/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9403
# Epoch 26: saving model to training-1/cp-0026.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.1707 - accuracy: 0.9403 - val_loss: 0.1679 - val_accuracy: 0.9375
# Epoch 27/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9386
# Epoch 27: saving model to training-1/cp-0027.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1660 - accuracy: 0.9386 - val_loss: 0.3395 - val_accuracy: 0.8963
# Epoch 28/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1948 - accuracy: 0.9331
# Epoch 28: saving model to training-1/cp-0028.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.1948 - accuracy: 0.9331 - val_loss: 0.1727 - val_accuracy: 0.9337
# Epoch 29/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9405
# Epoch 29: saving model to training-1/cp-0029.ckpt
# 164/164 [==============================] - 55s 334ms/step - loss: 0.1656 - accuracy: 0.9405 - val_loss: 0.3019 - val_accuracy: 0.8941
# Epoch 30/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9439
# Epoch 30: saving model to training-1/cp-0030.ckpt
# 164/164 [==============================] - 55s 333ms/step - loss: 0.1542 - accuracy: 0.9439 - val_loss: 0.2269 - val_accuracy: 0.9253
# Epoch 31/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9295
# Epoch 31: saving model to training-1/cp-0031.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1991 - accuracy: 0.9295 - val_loss: 0.1473 - val_accuracy: 0.9505
# Epoch 32/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9480
# Epoch 32: saving model to training-1/cp-0032.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.1454 - accuracy: 0.9480 - val_loss: 0.2457 - val_accuracy: 0.9184
# Epoch 33/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9514
# Epoch 33: saving model to training-1/cp-0033.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1319 - accuracy: 0.9514 - val_loss: 0.3604 - val_accuracy: 0.8956
# Epoch 34/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9432
# Epoch 34: saving model to training-1/cp-0034.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1560 - accuracy: 0.9432 - val_loss: 0.1775 - val_accuracy: 0.9390
# Epoch 35/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9571
# Epoch 35: saving model to training-1/cp-0035.ckpt
# 164/164 [==============================] - 55s 338ms/step - loss: 0.1234 - accuracy: 0.9571 - val_loss: 0.1359 - val_accuracy: 0.9550
# Epoch 36/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9592
# Epoch 36: saving model to training-1/cp-0036.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.1216 - accuracy: 0.9592 - val_loss: 0.1359 - val_accuracy: 0.9535
# Epoch 37/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9609
# Epoch 37: saving model to training-1/cp-0037.ckpt
# 164/164 [==============================] - 55s 338ms/step - loss: 0.1169 - accuracy: 0.9609 - val_loss: 0.2121 - val_accuracy: 0.9284
# Epoch 38/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9579
# Epoch 38: saving model to training-1/cp-0038.ckpt
# 164/164 [==============================] - 56s 340ms/step - loss: 0.1304 - accuracy: 0.9579 - val_loss: 0.1383 - val_accuracy: 0.9527
# Epoch 39/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9468
# Epoch 39: saving model to training-1/cp-0039.ckpt
# 164/164 [==============================] - 56s 338ms/step - loss: 0.1465 - accuracy: 0.9468 - val_loss: 0.1842 - val_accuracy: 0.9329
# Epoch 40/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9624
# Epoch 40: saving model to training-1/cp-0040.ckpt
# 164/164 [==============================] - 56s 338ms/step - loss: 0.1137 - accuracy: 0.9624 - val_loss: 0.1130 - val_accuracy: 0.9596
# Epoch 41/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9647
# Epoch 41: saving model to training-1/cp-0041.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.1053 - accuracy: 0.9647 - val_loss: 0.2396 - val_accuracy: 0.9154
# Epoch 42/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9527
# Epoch 42: saving model to training-1/cp-0042.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.1342 - accuracy: 0.9527 - val_loss: 0.1537 - val_accuracy: 0.9512
# Epoch 43/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9539
# Epoch 43: saving model to training-1/cp-0043.ckpt
# 164/164 [==============================] - 55s 335ms/step - loss: 0.1288 - accuracy: 0.9539 - val_loss: 0.2860 - val_accuracy: 0.9101
# Epoch 44/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9649
# Epoch 44: saving model to training-1/cp-0044.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1031 - accuracy: 0.9649 - val_loss: 0.1996 - val_accuracy: 0.9268
# Epoch 45/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9615
# Epoch 45: saving model to training-1/cp-0045.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1116 - accuracy: 0.9615 - val_loss: 0.1169 - val_accuracy: 0.9604
# Epoch 46/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9586
# Epoch 46: saving model to training-1/cp-0046.ckpt
# 164/164 [==============================] - 55s 336ms/step - loss: 0.1174 - accuracy: 0.9586 - val_loss: 0.2409 - val_accuracy: 0.9329
# Epoch 47/50
# 164/164 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9655
# Epoch 47: saving model to training-1/cp-0047.ckpt
# 164/164 [==============================] - 56s 338ms/step - loss: 0.0991 - accuracy: 0.9655 - val_loss: 0.1085 - val_accuracy: 0.9611
# Epoch 48/50
# 164/164 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9651
# Epoch 48: saving model to training-1/cp-0048.ckpt
# 164/164 [==============================] - 55s 338ms/step - loss: 0.1078 - accuracy: 0.9651 - val_loss: 0.0995 - val_accuracy: 0.9657
# Epoch 49/50
# 164/164 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9741
# Epoch 49: saving model to training-1/cp-0049.ckpt
# 164/164 [==============================] - 58s 353ms/step - loss: 0.0801 - accuracy: 0.9741 - val_loss: 0.0975 - val_accuracy: 0.9688
# Epoch 50/50
# 164/164 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9678
# Epoch 50: saving model to training-1/cp-0050.ckpt
# 164/164 [==============================] - 55s 337ms/step - loss: 0.0989 - accuracy: 0.9678 - val_loss: 0.1048 - val_accuracy: 0.9627

# %%
# copying checkpoints to Drive
# !cp -r training-1 '{prj_dir}/Training'

# %%
# getting metrics at every epoch
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# plotting metrics at every epoch
train_metrics = [train_acc, train_loss]
val_metrics = [val_acc, val_loss]
metrics = ['Acc', 'Loss']

plt.figure(figsize=(10, 10))

for i in range(2):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(EPOCHS), train_metrics[i], label=f'Train {metrics[i]}')
    plt.plot(range(EPOCHS), val_metrics[i], label=f'Val {metrics[i]}')
    plt.xlabel('Epochs')
    plt.ylabel(metrics[i])
    plt.title(f'Train and Val {metrics[i]}')
    plt.legend()

# %%
models_dir = f'{prj_dir}/Models' # models directory
# loading model if saved model is available
model = models.load_model(f'{models_dir}/2')

# %%
# loading weights if saved training is available
# cps_dir = f'{train_dir}/training-1/'

# latest_cp = tf.train.latest_checkpoint(os.path.dirname(cps_dir))
# model.load_weights(latest_cp) # latest weights

# model.load_weights(f'{cps_dir}cp-0049.ckpt') # best weights

# %% [markdown]
# ### 6. Model evaluation

# %%
# evaluating model using testing set
metrics = model.evaluate(test_set)
print(f'Loss : {round(100 * metrics[0], 2)}%')
print(f'Acc  : {round(100 * metrics[1], 2)}%')
# Out:
# 24/24 [==============================] - 495s 54ms/step - loss: 0.0781 - accuracy: 0.9792
# Loss : 7.81%
# Acc  : 97.92%

# %%
# predicting labels of testing set and getting their confidences
lbls_true = []
lbls_pred = [] # predicted integer labels
pred_confs = [] # confidences

for i in range(test_size):
    for imgs, lbls in test_set.take(i + 1):
        lbls_true.extend(lbls.numpy().tolist())

        pred_imgs = model.predict(imgs)
        for pred_img in pred_imgs:
            lbls_pred.append(np.argmax(pred_img))
            pred_confs.append(np.max(pred_img))
        break

# %%
# changing integer labels to class names
lbls_true_names = list(map(lambda x: class_names[x], lbls_true))
lbls_pred_names = list(map(lambda x: class_names[x], lbls_pred))

# %%
# getting confusion matrix
cf_matrix = confusion_matrix(lbls_true_names, lbls_pred_names, labels=class_names)
cf_matrix_title = 'Confusion Matrix using Test Set'
print(cf_matrix_title)
print(cf_matrix)
# Out:
# Confusion Matrix using Test Set
# [[108   0   0   1   0   0   0   0]
#  [  0  88   0   1   0   0   0   0]
#  [  0   0 115   0   0   0   0   0]
#  [  0   0   0 102   2   0   0   0]
#  [  0   0   2   1 113   0   2   0]
#  [  0   0   0   0   0  37   0   0]
#  [  0   4   0   2   0   0  81   0]
#  [  0   0   0   0   0   0   0 109]]

# %%
# plotting confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(cf_matrix, annot=True, fmt='g', 
            xticklabels=class_names, yticklabels=class_names, 
            cbar=False, cmap='YlOrBr')
plt.xlabel('Pred lbls')
plt.ylabel('True lbls')
plt.title(cf_matrix_title)
plt.show()

# %%
# getting precisions
pred_sums = np.sum(cf_matrix, axis=0)
prec_matrix = cf_matrix / pred_sums
precs = prec_matrix.diagonal()

# getting recalls
true_sums = np.sum(cf_matrix, axis=1)
recall_matrix = cf_matrix / true_sums
recalls = recall_matrix.diagonal()

# getting f1 measures
f1s = (2 * precs * recalls) / (precs + recalls)

# %%
# displaying testing set counts
counts_tbl = []
for i in range(len(class_names)):
    counts_tbl.append([class_names[i], true_sums[i]])
counts_tbl.append(['Test set', sum(true_sums)])

print('Test set counts:')
print(tabulate(counts_tbl, tablefmt='grid'))
# Out:
# Test set counts:
# +------------------------+-----+
# | Bacterial-spot         | 109 |
# +------------------------+-----+
# | Early-blight           |  89 |
# +------------------------+-----+
# | Healthy                | 115 |
# +------------------------+-----+
# | Late-blight            | 104 |
# +------------------------+-----+
# | Leaf-mold              | 118 |
# +------------------------+-----+
# | Mosaic-virus           |  37 |
# +------------------------+-----+
# | Septoria-leaf-spot     |  87 |
# +------------------------+-----+
# | Yellow-leaf-curl-virus | 109 |
# +------------------------+-----+
# | Test set               | 768 |
# +------------------------+-----+

# %%
# displaying evaluations
evals_df = pd.DataFrame(data={'Precision': precs, 'Recall': recalls, 'F1': f1s}, 
                        index=class_names)
pd.options.display.float_format = '{:.2%}'.format
evals_df
# Out:
#                         Precision  Recall      F1
# Bacterial-spot            100.00%  99.08%  99.54%
# Early-blight               95.65%  98.88%  97.24%
# Healthy                    98.29% 100.00%  99.14%
# Late-blight                95.33%  98.08%  96.68%
# Leaf-mold                  98.26%  95.76%  97.00%
# Mosaic-virus              100.00% 100.00% 100.00%
# Septoria-leaf-spot         97.59%  93.10%  95.29%
# Yellow-leaf-curl-virus    100.00% 100.00% 100.00%

# %%
macro_f1 = round(evals_df['F1'].mean() * 100, 2)
micro_f1 = round(np.sum(cf_matrix.diagonal()) / np.sum(cf_matrix) * 100, 2)
print(f'Macro F1: {macro_f1}%')
print(f'Micro F1: {micro_f1}%')
# Out:
# Macro F1: 98.11%
# Micro F1: 98.05%

# %%
# plotting distribution of confidences
plt.figure(figsize=(8, 8))
plt.hist(pred_confs)
plt.xlabel('Confidences')
plt.ylabel('Count')
plt.title('Distribution of Confidences using Test Set')
plt.show()

# %%
# displaying random image results
rand_batch = random.randint(1, test_size)
rand_img = random.randint(0, BATCH_SIZE - 1)

i = (rand_batch - 1) * BATCH_SIZE
lbl_true_name = lbls_true_names[i:i + BATCH_SIZE][rand_img]
lbl_pred_name = lbls_pred_names[i:i + BATCH_SIZE][rand_img]
pred_conf = pred_confs[i:i + BATCH_SIZE][rand_img]

print(f'True lbl : {lbl_true_name}')
print(f'Pred lbl : {lbl_pred_name}')
print(f'Conf     : {round(100 * pred_conf, 2)}%')

for imgs, lbls in test_set.take(rand_batch):
    plt.imshow(imgs[rand_img].numpy().astype('uint8'))
    plt.axis('off')
    break
# Out:
# True lbl : Leaf-mold
# Pred lbl : Leaf-mold
# Conf     : 99.99%

# %% [markdown]
# ### 7. Saving model

# %%
# saving latest model
model_ver = len(os.listdir(models_dir)) # latest saved model
model_ver += 1
model.save(f'{models_dir}/{model_ver}')

# %%
# model.save(f'{models_dir}/tomato-disease-detection-model.h5')
